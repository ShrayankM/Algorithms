# %%
points_x = [0.206107, 0.975528, 0.024472, 0.793893, 0.793893, 0.975528, 0.206107, 0.500000, 0.024472, 0.500000]

# %%
points_y  = [0.095492, 0.654508, 0.345492, 0.095492, 0.904508, 0.345492, 0.904508, 0.000000, 0.654508, 1.000000]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(points_x, points_y)

# %%
rect_x = [p * .01 for p in range(2, 9)]
rect_y = [p * .01 for p in range(2, 9)]
